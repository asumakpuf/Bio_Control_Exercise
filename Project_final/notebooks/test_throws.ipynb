# %%
from pathlib import Path
import sys

for base in [Path.cwd(), *Path.cwd().parents]:
    for candidate in (
        base / "additions" / "fable_2_api",
        base / "Required_Tools" / "additions" / "fable_2_api",
        base / "Exercises34752_week1" / "1.3" / "Required_Tools" / "additions" / "fable_2_api",
    ):
        if (candidate / "FableAPI").is_dir() and str(candidate) not in sys.path:
            sys.path.insert(0, str(candidate))
            break
    else:
        continue
    break

from FableAPI.fable_init import api
api.setup(blocking=True)
# Out:
# PORT: /dev/ttyACM0, NAME: Fable Dongle 1.5, HWID: USB VID:PID=03EB:FABE LOCATION=1-2:1.0
# Trying to connect /dev/ttyACM0 Linux implementation - tested!
# dongle connect: True
# Dongle...success
# setup done
# True

# %%
moduleids = api.discoverModules()
print("Module IDs: ", moduleids)

if not moduleids:
    raise RuntimeError("No Fable modules found. Check that the module is powered on and connected to the dongle.")
# Out:
# Runtime Created SE7
# Module IDs:  ['SE7 ']

# %%
# static position
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(0, 0, moduleID)
# Out:
# 0

# %%
# center position to throw to the center of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(0, -30, moduleID)
# Out:
# 0

# %%
# throw to the center of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(0, 60, moduleID)
# Out:
# 0

# %%
# base position to throw to the left of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-40, -45, moduleID)
# Out:
# 0

# %%
#  throw to the left of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-40, 38, moduleID)
# Out:
# 0
# Dongle not ready!  (<class 'OSError'>, OSError(5, 'Input/output error'), <traceback object at 0x744740707b80>)
# SE7 : Failed writing sync packet
# Dongle not ready!  (<class 'OSError'>, OSError(5, 'Input/output error'), <traceback object at 0x744740707980>)
# PORT: /dev/ttyS0, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS1, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS2, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS3, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS4, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS5, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS6, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS7, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS8, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS9, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS10, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS11, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS12, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS13, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS14, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS15, NAME: n/a, HWID: n/a
# PORT: /dev/ttyS16, NAME: n/a, HWID: n/a
# ...

# %%
# base position to throw to the right of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(40, -45, moduleID)
# Out:
# 0

# %%
#  throw to the rigth of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(40, 38, moduleID)
# Out:
# 0

# %%
# base position to throw to the  right  1 of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(35, -38, moduleID)
# Out:
# 0

# %%
#  throw to the  rigth 1 of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(35, 20, moduleID)
# Out:
# 0

# %%
# base position to throw to the  right  2 of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(20, -38, moduleID)
# Out:
# 0

# %%
#  throw to the  rigth 2 of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(20, 25, moduleID)
# Out:
# 0
# Exception in runtime thread!  (<class 'serial.serialutil.SerialException'>, SerialException('device reports readiness to read but returned no data (device disconnected or multiple access on port?)'), <traceback object at 0x7d2ac7204a80>)
# Traceback (most recent call last):
#   File "/home/chiara/dtu/bioinsp/Bio_Control_Exercise/Exercises34752_week1/1.3/Required_Tools/additions/fable_2_api/FableAPI/runtime.py", line 30, in run
#     self.sync()
#   File "/home/chiara/dtu/bioinsp/Bio_Control_Exercise/Exercises34752_week1/1.3/Required_Tools/additions/fable_2_api/FableAPI/runtime.py", line 168, in sync
#     success = m.sync()
#               ^^^^^^^^
#   File "/home/chiara/dtu/bioinsp/Bio_Control_Exercise/Exercises34752_week1/1.3/Required_Tools/additions/fable_2_api/FableAPI/jointManager.py", line 164, in sync
#     res, packet = self.sendSyncMessage(headerData, writeData, readData)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# base position to throw to the  left  2 of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-20, -38, moduleID)
# Out:
# 0

# %%
#  throw to the  left 2 of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-20, 25, moduleID)
# Out:
# 0

# %%
# base position to throw to the  left 1 of the target line
moduleID = moduleids[0]

speed = 10  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-35, -38, moduleID)
# Out:
# 0

# %%
#  throw to the left 1 of the target line
moduleID = moduleids[0]

speed = 100  # 1-100 percent; 100 is fastest
api.setSpeed(speed, speed, moduleID)
api.setPos(-35, 20, moduleID)
# Out:
# 0
